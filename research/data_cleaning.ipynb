# %%
import pandas as pd

# %%
df = pd.read_csv("../data/train.csv")

# %%
noice = [194,
2786,
4089,
8976,
16129,
16657,
21436,
33131,
35647,
37160,
38123,
46061,
59962]

# %%
df.loc[noice]
# Out:
#           id         word  stress  num_syllables        lemma
# 194      194      постриг       2              2      постриг
# 2786    2786     быстроты       3              3     быстрота
# 4089    4089         суши       1              2         суша
# 8976    8976         ломы       1              2          лом
# 16129  16129        устюг       1              2        устюг
# 16657  16657      бересты       1              3      береста
# 21436  21436      пучками       2              3        пучок
# 33131  33131     подарена       2              4     подарить
# 35647  35647         зада       1              2          зад
# 37160  37160      кратера       1              3       кратер
# 38123  38123  заснеженной       2              4  заснеженный
# 46061  46061      раздели       3              3    разделять
# 59962  59962        танке       1              2         танк

# %%
df["stress"][194] = 2
df["stress"][2786] = 3
df["stress"][4089] = 1
df["stress"][8976] = 1
df["stress"][16129] = 1
df["stress"][16657] = 1
df["stress"][21436] = 2
df["stress"][33131] = 2
df["stress"][35647] = 1
df["stress"][37160] = 1
df["stress"][38123] = 2
df["stress"][46061] = 3
df["stress"][59962] = 1

df = df.drop([2008, 23593, 57741])
# Out:
# C:\Users\eugen\AppData\Local\Temp\ipykernel_16304\3995402153.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["stress"][194] = 2
# C:\Users\eugen\AppData\Local\Temp\ipykernel_16304\3995402153.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["stress"][2786] = 3
# C:\Users\eugen\AppData\Local\Temp\ipykernel_16304\3995402153.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["stress"][4089] = 1
# ...

# %%
df.to_csv("../data/cleaned_dataset.csv", index=False)
